# %% [markdown]
# ![imagen](./img/seaborn.png)
#
#
# # Exploratory Data Analysis with Seaborn
# Entender cómo se hacen las gráficas en python está muy bien, pero lo importante es saber cuándo usarlas. En este notebook no se pretende explicar todos los tipos de gráficas que hay (histogramas, scatter plots, heatmaps...), en primer lugar porque es imposible abarcarlo todo, y en segundo lugar porque hay que ir un paso atrás antes de elegir la gráfica, ya que tenemos que comprender de qué tipo son los datos y qué es lo que estamos buscando con cada gráfica.
#
# Por tanto, primero tendremos que identificar el tipo de los datos y cuántas variables vamos a representar
# - Una varibale numérica
# - Una variable categórica
# - Dos variables numércias
# - Tres o más variables numércias
# - Dos variablees categóricas
# - Variables numércias y categóricas
#
# Teniendo claro esto, junto con un buen catálogo de gráficas, lo tendremos mucho más fácil.
#
# https://www.data-to-viz.com/

# %%
# Importamos todos los paquetes que vayamos a necesitar
from sklearn.datasets import load_iris, fetch_california_housing
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Algunas configuraciones de los paquetes
pd.set_option("display.max_rows", 500) # Cuántas filas de los DataFrames nos "escupe" pandas en el Notebook
sns.set(color_codes=True)

#import warnings
#warnings.filterwarnings("ignore")

# %%
import sklearn
sklearn.__version__
# Out:
# '1.7.2'

# %%
# Cargamos las features en un DataFrame:
iris_df = pd.DataFrame(load_iris()["data"],columns=load_iris()["feature_names"])

# Casas de Boston 
boston_df = pd.read_csv('data/boston_house_prices.csv', header=1)

# Cargamos dataset de suicidios
suicid_df = pd.read_csv("data/suicide.csv")

# Y añadimos la columna de especies:
iris_df["target"] = load_iris()["target_names"][load_iris()["target"]]

# Cargamos tb el dataset del titanic
titanic_df = pd.read_csv("data/titanic.csv", sep="\t")

# Cargamos los datos del supermarket sales
market_df = pd.read_csv("data/supermarket_sales.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
market_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# # Tipos de las variables
# Antes de representar cualquier variable es imprescindible comprender qué tipo de datos queremos representar. Tenemos los siguientes:
#
# ![imagen](./img/dtypes.png)

# %% [markdown]
# ## 1. Análisis univariante
# [Explicación Analisis univariante](analisis_univariante.md)
#
# ### 1.1 Variables cuantitativas(Numericas) (Cuanto es)
# Las variables cuantitativas son aquellas que representan valores numéricos y permiten realizar operaciones matemáticas como sumar, restar, calcular promedios, etc.
# En otras palabras: miden cantidades.
#
# Si queremos ver cómo se distribuyen los precios de venta de tickets del Titanic.
# #### Densidad
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Este tipo de gráficas nos sirven para ver la distribución de los datos, donde se concentran más, ¿es dispersa? ¿tiene asimétrica? ¿por qué? ¿Hay outliers?

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(titanic_df["Fare"]);

# %% [markdown]
# #### Histograma
# También podemos verlo en un histograma
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Los histogramas dan la frecuencia de aparición de todos los valores. Muy similar al diagrama de densidad anterior. La diferencia es que ahora el eje y es un conteo y no la probabilidad de aparición de los valores de la variable.

# %%
plt.figure(figsize=(10,5))
sns.histplot(titanic_df["Fare"], kde=False, color = "g");

# %% [markdown]
# Podemos agrupar (visualmente) una variable numérica. Podría ser una posible categorización de los billetes

# %%
plt.figure(figsize=(10,5))
sns.histplot(titanic_df["Fare"], kde=False, color="g", bins = 3);

# %% [markdown]
# #### Histograma + Densidad

# %%
plt.figure(figsize=(10,5))
sns.histplot(titanic_df["Fare"],kde=True, stat="density", linewidth=3);

# %% [markdown]
# Otra manera muy visual de ver la concentración de los valores es mediante el argumento `rug`

# %%
#El rugplot añade pequeñas marcas (rayitas verticales) en el eje X.
#Cada rayita representa un valor de Fare en los datos.
#Sirve para ver dónde se concentran los puntos sin perder la información individual. 

plt.figure(figsize=(10,5))
sns.histplot(titanic_df["Fare"], kde=True, stat="density", linewidth=3);

sns.rugplot(titanic_df["Fare"]);

# %% [markdown]
# #### Boxplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)
#
# [Tutorial Outliers](outliers_analisis_datos.ipynb)
#
# Los boxplots dan una información muy parecida a los gráficos vistos anteriormente, aunque en este caso destaca mucho más los outliers.

# %%
plt.figure(figsize=(20,5))
sns.boxplot(titanic_df["Fare"], color="sienna", orient="h")
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# ![imagen](./img/boxplot.png)

# %% [markdown]
# #### Violinplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html)
#
# Igual que un diagrama de caja, pero en este caso tiene la función de distribución en lugar de la propia caja

# %%
plt.figure(figsize=(20,5))
sns.violinplot(data = titanic_df["Fare"], color = "deeppink")
# Out:
# <Axes: ylabel='Fare'>

# %%
plt.figure(figsize=(20,5))
sns.violinplot(data = titanic_df["Fare"], color = "deeppink", inner = "stick");

# %% [markdown]
# ### 1.2 Variables cualitativas(Categoricas) (qué es)
# Para representar una variable categórica tendremos que ver su frecuencia de valores
# Una variable cualitativa/categorica es un tipo de variable que describe cualidades, categorías o características que no son numéricas.
# No se expresan en cantidades, sino en atributos o modalidades.  (sexo, marca de coche etc... )
#
# En este caso vamos a ver qué tipo de embarque ha sido el más frecuente.
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
plt.figure(figsize=(7,5))
sns.countplot(x = titanic_df["Embarked"]);

# %% [markdown]
# #### Lollipop
#
# ¿Cuáles han sido los productos más pedidos?
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hlines.html)

# %%
conteo = market_df['Product line'].value_counts(ascending=True)

plt.figure(figsize=(10,5))
plt.hlines(y=conteo.index,
           xmin=140,
           xmax=conteo,
           color='skyblue')
plt.plot(conteo, conteo.index, "o");

# %% [markdown]
# #### Donut chart/Pie chart
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html)

# %%
import matplotlib.pyplot as plt
 
# create data
data = titanic_df["Embarked"].value_counts()
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
# pie chart

plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%.5f%%');

# %% [markdown]
# ## 2. Análisis Bivariante
# ### 2.1 Comparativa de variables cuantitativas (2-4 variables numericas)
# #### Boxplot
#
# En este ejemplo veremos cómo de diferentes son las distribuciones de las 4 características que definen a una flor.
#
# [Boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=iris_df[iris_df.columns.values[0:4]])
# Out:
# <Axes: >

# %% [markdown]
# El boxplot está bien, pero haay algo de información que se nos escapa

# %%
plt.figure(figsize=(10,10))

# Hacemos un boxplot primero
sns.boxplot(data=iris_df[iris_df.columns.values[0:4]], palette="pastel")

# Añadimos puntos con swarmplot encima (se ven mejor que stripplot en este caso)
sns.swarmplot(data=iris_df[iris_df.columns.values[0:4]], color="black", alpha=0.6, size=3)

plt.title("Boxplot con distribución de puntos (Iris)", fontsize=16)
plt.show()

# %% [markdown]
# #### Diagramas de densidad
#
# Otra manera de ver cómo se distribuyen las características de las flores.
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data = iris_df[iris_df.columns.values[:4]], fill = True);

# %% [markdown]
# #### Histogramas
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
plt.figure(figsize=(12,8))
sns.histplot(iris_df["sepal length (cm)"] , color="skyblue", label="Sepal Length", kde=True, stat="density", linewidth=3)
sns.histplot(iris_df["sepal width (cm)"] , color="red", label="Sepal Width", kde=True, stat="density", linewidth=3)
plt.legend();

# %%
f, axes = plt.subplots(2, 2, figsize=(15,10), sharex=True)
sns.histplot(iris_df["sepal length (cm)"] , color="skyblue", ax=axes[0, 0], kde=True, stat="density", linewidth=3)
sns.histplot(iris_df["sepal width (cm)"] , color="olive", ax=axes[0, 1], kde=True, stat="density", linewidth=3)
sns.histplot(iris_df["petal length (cm)"] , color="gold", ax=axes[1, 0], kde=True, stat="density", linewidth=3)
sns.histplot(iris_df["petal width (cm)"] , color="teal", ax=axes[1, 1], kde=True, stat="density", linewidth=3);

# %% [markdown]
# #### Scatter plot
#
# En este ejemplo se ve claramente cómo estas dos variables sirven para distinguir las setosas de los otros tipos
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
#
# [Paradoja de Simpsons](https://es.wikipedia.org/wiki/Paradoja_de_Simpson)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x = iris_df["sepal length (cm)"],
y = iris_df["sepal width (cm)"],
s = 100,
hue = iris_df["target"]);

# %% [markdown]
# <img src="./img/simpson.jpg" width="1200">

# %% [markdown]
# ### Joinplot
#
# [Documentación jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
#
# Poblacion con poco poder adquisitivo vs media de habitaciones por vivienda
#
# A medida que aumenta el valor de LSTAT (más porcentaje de población con bajos ingresos),
# el valor de RM tiende a disminuir (menos habitaciones por vivienda).
# Esto indica que en zonas con mayor pobreza, las casas tienden a ser más pequeñas.

# %%
boston_df = pd.read_csv('data/boston_house_prices.csv', header=1)
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              color="#4CB391",
             height = 8);

# %%
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              kind="hex",
              color="#4CB391");

# %%
plt.figure(figsize=(8,8))
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              kind="kde",
              color="#4CB391");

# %% [markdown]
# ### 2.2 Comparativa de múltiples numéricas

# %% [markdown]
# #### Heatmaps
#
# Los heatmaps son perfectos para representar una matriz de correlación
#
# [Documentación heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(boston_df.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(boston_df.corr(),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=-1,
            vmax=1, cmap="coolwarm");

# %%
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(boston_df.corr(),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=-1,
            vmax=1,
            cmap="RdBu");

# %%
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(boston_df.corr(),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=-1,
            vmax=1,
            cmap="viridis");

# %% [markdown]
# También nos permite comparar una variable numérica vs variables categóricas.
#
# Se recomienda que las dos variables categóricas tengan pocos casos, porque si no, no se va a ver bien el heatmap.

# %%
data = market_df.groupby(["Product line", "Payment"]).sum()["Quantity"].unstack()
data = data.loc[["Electronic accessories", "Fashion accessories", "Food and beverages"]]

# %%
data
# Out:
# Payment                 Cash  Credit card  Ewallet
# Product line
# Electronic accessories   398          262      311
# Fashion accessories      280          293      329
# Food and beverages       295          335      322

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data,
square=True,
fmt=".2f",
cmap="coolwarm",
#cbar=False, # para poner la barra lateal o no 
annot=True,
linewidths = .3);
cmap="coolwarm",

# %% [markdown]
# #### Correlograma
#
# [Documentación Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# Interesante gráfica para ver en un dataset qué variables presentan correlación lineal, así como sus distribuciones. NO realices esta gráfica con muchas varaibles porque no se va a ver bien. Hazlo por partes.

# %%
sns.pairplot(iris_df);

# %%
sns.pairplot(iris_df,
kind = "scatter",
hue = "target",
plot_kws = dict(s = 80, edgecolor = "white", linewidth = 2));

# %%
sns.pairplot(iris_df,
             kind="scatter",
             hue="target",
             diag_kind="hist");

# %% [markdown]
# ### 2.3 Comparativa de dos variables cualitativas
# #### Tabla
#
# [Documentacion](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)
#
# Lo más sencillo, una tabla con la frecuencia de valores. Esto es factible cuando los elementos únicos por categoría no son muchos.

# %%
pd.crosstab(titanic_df["Embarked"],
            titanic_df["Sex"],
            margins = False)
# Out:
# Sex       female  male
# Embarked
# C             11    21
# Q              7     6
# S             37    73

# %% [markdown]
# #### Diagrama de barras
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.catplot.html)
#
# En un diagrama de barras también se entiende la representación de dos variables cualitativas

# %%
sns.catplot(x="Embarked",
            hue="Sex",
            kind="count",
            edgecolor=".6",
            orient = "V",
            data=titanic_df);

# %% [markdown]
# Otra manera de visualizar dos o más variables categóricas

# %%
plt.figure(figsize=(30,10));
sns.catplot(x="Survived",
            col="Embarked",
            col_wrap=4,
            data=titanic_df,
            kind="count");

# %%
df_plot = titanic_df.groupby(['Embarked', 'Survived']).size().reset_index().pivot(columns='Embarked',
                                                                                  index='Survived',
                                                                                  values=0)
df_plot.plot(kind='bar', stacked=True);

# %%
sns.catplot(x="Sex",
            y="Survived",
            hue="Embarked",
            kind="bar",
            data=titanic_df,
            ci=None); # Para que elimine las barras de error
# Out:
# C:\Users\borja\AppData\Local\Temp\ipykernel_16552\426859370.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="Sex",

# %% [markdown]
# ### 2.4 Cualitativa vs cuantitativa
# #### Time series
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
#
# Las series temporales tienen la particularidad de que son datos ordenados

# %% [markdown]
# ####

# %%
suicid_df2 = suicid_df[suicid_df['country'].isin(['Spain', 'Germany', 'France'])]
suicid_df2 = suicid_df2.groupby(['country', 'year']).sum()
suicid_df2.reset_index(inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=suicid_df2,
             x="year",
             y="suicides_no",
             hue="country",
            linewidth = 3);

# %% [markdown]
# #### Treemap
# Un treemap es una opción muy interesante para mostrar una variable numérica vs una categórica

# %%
suicid_df.groupby("country").sum()['suicides_no'].sort_values(ascending=False)[:30]
# Out:
# country
# Russian Federation    1209742
# United States         1034013
# Japan                  806902
# France                 329127
# Ukraine                319950
# Germany                291262
# Republic of Korea      261730
# Brazil                 226613
# Poland                 139098
# United Kingdom         136805
# Italy                  132060
# Mexico                 111139
# Thailand               110643
# Canada                 107561
# Kazakhstan             101546
# Spain                  100202
# Argentina               82219
# Hungary                 73891
# Romania                 72777
# Australia               70111
# Belgium                 62761
# Belarus                 59892
# Sri Lanka               55641
# Colombia                53080
# Netherlands             50833
# Austria                 50073
# Czech Republic          43687
# Cuba                    41418
# Chile                   40895
# Sweden                  37795
# Name: suicides_no, dtype: int64

# %%
import squarify

data = suicid_df.groupby("country").sum()['suicides_no'].sort_values(ascending=False)[:10]

plt.figure(figsize=(15,10))
squarify.plot(sizes=data.values, label=data.index, alpha=.8 )
plt.axis('off')
plt.title("Suicidios por país")
plt.show()

# %% [markdown]
# Con este catplot obtenemos la dispersión de la variable Age, por cada grupo de la categoría.

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", data=titanic_df);

# %% [markdown]
# El equivalente con un diagrama de caja (Boxplot) sería el siguiente

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="box", data=titanic_df);

# %% [markdown]
# El equivalente con un diagrama Violin sería el siguiente

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="violin", data=titanic_df);

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="violin", split=True, data=titanic_df);

# %%
sns.catplot(
    x="Survived",       # Eje X: indica si sobrevivió (0 = no, 1 = sí)
    y="Fare",           # Eje Y: la tarifa pagada por el pasajero
    hue="Sex",          # Colorea los puntos según el sexo (hombre/mujer)
    col="Embarked",     # Crea una columna (subgráfico) por cada puerto de embarque
    data=titanic_df,    # Dataset que contiene la información (DataFrame Titanic)
    height=5,           # Altura de cada subgráfico
    aspect=.8           # Relación ancho/alto de cada subgráfico

# %%
# Filtramos el DataFrame original para quedarnos solo con 4 países
suicid_df2 = suicid_df[suicid_df['country'].isin(['Spain', 'Germany', 'France', 'Japan'])]

# Creamos un gráfico categórico con seaborn
chart = sns.catplot(
    x="age",                   # Eje X: grupos de edad
    y="suicides/100k pop",     # Eje Y: tasa de suicidios por cada 100k habitantes
    hue="sex",                 # Colores: diferencia entre hombres y mujeres
    col="country",             # Crea una columna (subplot) por país
    data=suicid_df2,           # Usamos solo los países filtrados
    height=8,                  # Altura de cada gráfico
    aspect=.8                  # Relación ancho/alto de cada gráfico
)

# Rotamos las etiquetas del eje X para que no se solapen
chart.set_xticklabels(rotation=45)

# %%
import seaborn as sns

sns.catplot(
    x="Fare",            # Eje X: tarifa del billete
    y="Embarked",        # Eje Y: puerto de embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
    hue="Sex",           # Colores: diferencia entre hombres y mujeres
    kind="violin",       # Tipo de gráfico: violín (muestra distribución de los datos)
    col="Survived",      # Separa en dos columnas según supervivencia (0 = no, 1 = sí)
    bw_adjust=.1,               # Suavizado del violín (bandwidth); valores pequeños = más detalle
    height=8,            # Altura de cada subgráfico
    aspect=.8,           # Relación ancho/alto de cada subgráfico
    data=titanic_df      # Dataset Titanic
)

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(
   data=titanic_df, x="Fare", hue="Embarked",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
);

# %%
suicid_df2 = suicid_df[suicid_df['country'] == 'Spain']

plt.figure(figsize=(20,8))
sns.barplot(x="year",
            y="suicides_no",
            palette="Blues_d",
            data=suicid_df2,
           ci=None);
# Out:
# C:\Users\borja\AppData\Local\Temp\ipykernel_16552\1073450135.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="year",
# C:\Users\borja\AppData\Local\Temp\ipykernel_16552\1073450135.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="year",

# %%
# Filter countries with 'gdp_per_capita > 10000
df1 = suicid_df.groupby('country').sum()['suicides_no']
df2 = suicid_df[suicid_df['gdp_per_capita ($)'] > 10000].groupby('country').sum()['suicides_no']
df1 = df1[df1.index.isin(df2.index)]

df_tot = pd.DataFrame({"Tot_suicide": df1, "Suicide_gdp": df2}).sort_values("Tot_suicide", ascending=False)[:20]
df_tot.reset_index(level=0, inplace=True)
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="Tot_suicide", y="country", data=df_tot,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Suicide_gdp", y="country", data=df_tot,
            label="High gdp", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
sns.despine(left=True, bottom=True)

# %% [markdown]
# #### Bubble chart

# %%
suicid_df[suicid_df['country-year'] == 'Spain2002']
# Out:
#       country  year     sex          age  suicides_no  population  \
# 23732   Spain  2002    male    75+ years          498     1171341
# 23733   Spain  2002    male  55-74 years          688     3804296
# 23734   Spain  2002    male  35-54 years          752     5784305
# 23735   Spain  2002    male  25-34 years          414     3566812
# 23736   Spain  2002  female    75+ years          154     1934508
# 23737   Spain  2002    male  15-24 years          196     2855801
# 23738   Spain  2002  female  55-74 years          268     4260724
# 23739   Spain  2002  female  35-54 years          245     5794565
# 23740   Spain  2002  female  25-34 years          103     3417162
# 23741   Spain  2002  female  15-24 years           46     2719911
# 23742   Spain  2002    male   5-14 years            7     2069866
# 23743   Spain  2002  female   5-14 years            1     1961320
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 23732              42.52    Spain2002           NaN    705,145,868,624
# 23733              18.08    Spain2002           NaN    705,145,868,624
# 23734              13.00    Spain2002           NaN    705,145,868,624
# 23735              11.61    Spain2002           NaN    705,145,868,624
# 23736               7.96    Spain2002           NaN    705,145,868,624
# 23737               6.86    Spain2002           NaN    705,145,868,624
# 23738               6.29    Spain2002           NaN    705,145,868,624
# 23739               4.23    Spain2002           NaN    705,145,868,624
# 23740               3.01    Spain2002           NaN    705,145,868,624
# 23741               1.69    Spain2002           NaN    705,145,868,624
# 23742               0.34    Spain2002           NaN    705,145,868,624
# 23743               0.05    Spain2002           NaN    705,145,868,624
#
#        gdp_per_capita ($)    generation
# 23732               17924        Silent
# 23733               17924        Silent
# 23734               17924       Boomers
# 23735               17924  Generation X
# 23736               17924        Silent
# 23737               17924    Millenials
# 23738               17924        Silent
# 23739               17924       Boomers
# 23740               17924  Generation X
# 23741               17924    Millenials
# 23742               17924    Millenials
# 23743               17924    Millenials

# %%
suicid_df2 = suicid_df[suicid_df['country-year'] == 'Spain2002']

sns.relplot(data=suicid_df2,
            x="suicides_no",
            y="suicides/100k pop",
            hue="sex", size="age",
            sizes=(4, 300),
            alpha=.5, palette="muted",
            height=6);
