# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿Por qué esta magnifica tecnología cientifica, \n\tque ahorra trabajo y nos hace la vida más facil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tel final de la frase \n\"Albert\"")
# Out:
# ¿Por qué esta magnifica tecnología cientifica,
# 	que ahorra trabajo y nos hace la vida más facil,
# 		nos aporta tan poca felicidad?
# 			el final de la frase
# "Albert"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = 'Recoletos'
numero = 15 
cuidad = 'Madrid'
cp = 28015 

print(calle, numero, cuidad, cp)

print(f'Mi direccion es {calle}')
# Out:
# Recoletos 15 Madrid 28015
# Mi direccion es Recoletos

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input("Introduce tu calle")
numero = int(input("introduce el numero"))
cuidad = input("introduce tu cuidad")

print(calle,numero,cuidad)

print(f'Tu paquete sera entregado en la calle {calle}, numero {numero} en la cuidad de {cuidad}')
# Out:
# recoletos 15 madrid
# Tu paquete sera entregado en la calle recoletos, numero15 en la cuidad de madrid

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %%
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
""" 
hola mundo estoy currando 
""" 
c = float(input("Introduzca los grados celsius:").replace(",","."))  # he aprendido a usar replace que sirve para reemplazar un objeto por otro es util 
f = c * (9/5) + 32 

print(f)
# Out:
# 73.4

# %%
float(input("Introduzca los grados celsius:").replace(",","."))
# Out:
# 34.98

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código. Indica cuál es el input y el output de tu código.
